# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

cdf = pd.read_csv('/Users/eqtrq/python/kdc_d.csv', sep=',', header=0)
cdf

cdf_1 = cdf['call_no'].values.tolist()
cdf_1

cdf_2=cdf["call_no"].str.split(" ")
cdf_2
cdf["front"] = cdf_2.str.get(0)
cdf["back"] = cdf_2.str.get(1)
cdf

cdfl=cdf['front']
cdfl

cdfld=cdfl.to_frame()
cdfld

cdfld1=cdfld.value_counts()
cdfld1.to_csv("call_num_counts1.csv", mode='w',encoding='utf-8-sig')

cdfld2=cdfld["front"].str.split(".")
cdfld2

cdfld["front"] = cdfld2.str.get(0)
cdfld["back"] = cdfld2.str.get(1)
cdfld

cdfld3=cdfld['front'].to_frame()
cdfld3

cdfld3=cdfld['front'].value_counts()
cdfld3.to_csv("call_num_counts2.csv", mode='w',encoding='utf-8-sig')
# Out:
#            call_no
# 0       843 매821ㄴ임
# 1        843 뉴31ㅂ홍
# 2    843 콜239ㅎ이 -1
# 3       813.6 정67ㅊ
# 4       001.3 박67ㅊ
# ..             ...
# 238     340.1 김64ㅇ
# 239      818 전58ㄷ
# 240   199.7 브237ㅇ이
# 241   688.018 김94ㅂ
# 242  911.004 최832ㅇ
#
# [243 rows x 1 columns]

# %%
# Out:
# ['843 매821ㄴ임',
#  '843 뉴31ㅂ홍',
#  '843 콜239ㅎ이 -1',
#  '813.6 정67ㅊ',
#  '001.3 박67ㅊ',
#  '381.7 랭63ㅇ조',
#  '029.1 최72ㅌ',
#  '833.6 동62ㄴ양',
#  '831.6 시73ㅇ채',
#  '843.6 플239ㄴ강',
#  '813.7 김64ㅅ',
#  '811.609 고94ㅂ',
#  '813.7 박91ㅈ',
#  '802 강67ㄷ',
#  '802.1 한58ㄴ',
#  '811.609 김817ㅊ',
#  '811.9 성43ㅎ',
#  '816.7 양73ㅂ',
#  '859.7 베828ㅇ최',
#  '699.2 황69ㅍ',
#  '811.9 이67ㄹ',
#  '594.5 오819ㅇ김',
#  '811.609 정72ㅅ',
#  '982.02 오72ㅎ',
#  '811.7 박77ㄷ',
#  '818 이64ㅅ',
#  '802.041 김73ㄴ',
#  '594.504 박64ㅇ',
#  '811.609 김68ㅊ',
#  '811.6 윤225ㅎ',
#  '013.33 북215ㅇ',
#  '843.6 워833ㅍ최',
#  '811.6 한11ㅅ',
#  '404 김51ㄱ',
#  '802.1 나218',
#  '657.1 릭58ㅁ류',
#  '814.7 김57ㄴ',
#  '843.6 창833ㄷ김',
#  '811.7 나832ㄲ',
#  '811.7 나832ㄱ',
#  '814.7 박77ㅇ',
#  '814.7 안214ㅇ',
#  '833.6 동62ㅇ양',
#  '811.09 정72ㄱ',
#  '818 루59ㅁ',
#  '813.7 김97ㄴ2',
#  '189.1 맨58ㅅ한',
#  '199.1 서77ㅇ',
#  '029.1 유59ㅊ2',
#  '325.04 도838ㅈ손',
#  '594.5 유14ㄱ',
#  '843.6 토235김',
#  '811.7 이44ㅂ',
#  '818 김55ㅈ',
#  '818 하66ㅎ',
#  '029.8 최58ㄱ',
#  '818 윤73ㅎ',
# ...

# %%
# Out:
#            call_no    버리는문자    front    back
# 0       843 매821ㄴ임      843      843  매821ㄴ임
# 1        843 뉴31ㅂ홍      843      843   뉴31ㅂ홍
# 2    843 콜239ㅎ이 -1      843      843  콜239ㅎ이
# 3       813.6 정67ㅊ    813.6    813.6    정67ㅊ
# 4       001.3 박67ㅊ    001.3    001.3    박67ㅊ
# ..             ...      ...      ...     ...
# 238     340.1 김64ㅇ    340.1    340.1    김64ㅇ
# 239      818 전58ㄷ       818      818    전58ㄷ
# 240   199.7 브237ㅇ이    199.7    199.7  브237ㅇ이
# 241   688.018 김94ㅂ  688.018  688.018    김94ㅂ
# 242  911.004 최832ㅇ  911.004  911.004   최832ㅇ
#
# [243 rows x 4 columns]

# %%
# Out:
# 0          843
# 1          843
# 2          843
# 3        813.6
# 4        001.3
#         ...
# 238      340.1
# 239        818
# 240      199.7
# 241    688.018
# 242    911.004
# Name: front, Length: 243, dtype: object

# %%
# Out:
#        front
# 0        843
# 1        843
# 2        843
# 3      813.6
# 4      001.3
# ..       ...
# 238    340.1
# 239      818
# 240    199.7
# 241  688.018
# 242  911.004
#
# [243 rows x 1 columns]

# %%
# Out:
# 0           [843]
# 1           [843]
# 2           [843]
# 3        [813, 6]
# 4        [001, 3]
#           ...
# 238      [340, 1]
# 239         [818]
# 240      [199, 7]
# 241    [688, 018]
# 242    [911, 004]
# Name: front, Length: 243, dtype: object

# %%
# Out:
#     front back
# 0     843  NaN
# 1     843  NaN
# 2     843  NaN
# 3     813    6
# 4     001    3
# ..    ...  ...
# 238   340    1
# 239   818  NaN
# 240   199    7
# 241   688  018
# 242   911  004
#
# [243 rows x 2 columns]

# %%
# Out:
#     front
# 0     843
# 1     843
# 2     843
# 3     813
# 4     001
# ..    ...
# 238   340
# 239   818
# 240   199
# 241   688
# 242   911
#
# [243 rows x 1 columns]
